# %%
# from 23B

# %%
import csv
# import cv2
import os
# import tensorflow as tf
# import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.layers import Dense, Flatten, Conv2D
# from tensorflow.keras import Model
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# python standard libraries
# import os
# from os import path

import random
import fnmatch
import datetime
import pickle

# data processing
import numpy as np
np.set_printoptions(formatter={'float_kind':lambda x: "%.4f" % x})



import pandas as pd
pd.set_option('display.width', 300)
pd.set_option('display.float_format', '{:,.4f}'.format)
pd.set_option('display.max_colwidth', 200)

# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import regularizers
from tensorflow.keras.models import Sequential  # V2 is tensorflow.keras.xxxx, V1 is keras.xxx
from tensorflow.keras.layers import Conv2D, Concatenate, MaxPool2D, BatchNormalization, Dropout, Flatten, Dense, Input, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
print( f'tf.__version__: {tf.__version__}' )
print( f'keras.__version__: {keras.__version__}' )

# sklearn
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# imaging
import cv2
from imgaug import augmenters as img_aug
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image, ImageEnhance
# Out:
# tf.__version__: 2.4.1
# keras.__version__: 2.4.0

# %%
yy = []
xx = []

with open('train_flip_correct.csv', mode='r') as infile:
    reader = csv.reader(infile)
    next(reader)
#     print(reader)
    with open('training_norm_new.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
#         c = 0
        for rows in reader:
#             if c > 100:
#                 break
            f = rows[0]
            a = float(rows[1])
            s = float(rows[2])
            yy.append(s)
            filename = str(f)
            xx.append(filename)

# %%
directory_annotations = '/Users/Kamyab/Documents/UoN/MLiS_2/Project/Redesigned/'
x_names=[]
y=[]
for file in os.listdir(directory_annotations):
    if file == '.DS_Store' or file == '.DS_S.xml':
        continue
    
    if '_' in file:
        f=(file.split('_')[0])
    else:
        f=(file.split('.')[0])
    x_names.append(file)
    y.append(yy[xx.index(f)])

# %%
print(np.shape(x_names))
# Out:
# (38860,)

# %%
print(np.shape(y))
# Out:
# (38860,)

# %%
def image_data_generator(image_paths, steering_angles, batch_size, is_training, shuffle=True):
    num_batches = int(np.floor(len(image_paths) / batch_size))
    bc = 0
#     print('bc ', bc)
    indexes = np.arange(len(image_paths))
    if shuffle == True:
            np.random.shuffle(indexes)
    while True:
        batch_images = []
        batch_steering_angles = []
        path = '/Users/Kamyab/Documents/UoN/MLiS_2/Project/Redesigned/'
       
        for i in range(batch_size):
            index = bc * batch_size + i  
#             print('bc, i, index, indexes, is_training = ', bc, i, index, indexes[index], is_training)
            image_path = path + image_paths[indexes[index]]
            image = cv2.imread(image_path)
            steering_angle = steering_angles[indexes[index]]
#             if is_training:
#                 # training: augment image
#                 image, steering_angle = random_augment(image, steering_angle)
             
            image = img_preprocess(image)
            batch_images.append(image)
            batch_steering_angles.append(steering_angle)
        bc += 1 
        if bc >= num_batches:
            bc = 0
            if shuffle == True:
                np.random.shuffle(indexes)        
        yield( np.asarray(batch_images), np.asarray(batch_steering_angles))

# %%
X_train, X_valid, y_train, y_valid = train_test_split( x_names, y, test_size=0.2)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))
# Out:
# Training data: 31088
# Validation data: 7772

# %%
def zoom(image):
    zoom = img_aug.Affine(scale=(1, 1.3))  # zoom from 100% (no zoom) to 130%
    image = zoom.augment_image(image)
    return image

# %%
def pan(image):
    # pan left / right / up / down about 10%
    pan = img_aug.Affine(translate_percent= {"x" : (-0.1, 0.1), "y": (-0.1, 0.1)})
    image = pan.augment_image(image)
    return image

# %%
def adjust_brightness(image):
    # increase or decrease brightness by 30%
    brightness = img_aug.Multiply((0.7, 1.3))
    image = brightness.augment_image(image)
    return image

# %%
def blur(image):
    kernel_size = random.randint(1, 5)  # kernel larger than 5 would make the image way too blurry
    image = cv2.blur(image,(kernel_size, kernel_size))
   
    return image

# %%
def random_flip(image, steering_angle):
#     is_flip = random.randint(0, 1)
#     if is_flip == 1:
        # randomly flip horizon
    image = cv2.flip(image,1)
#     steering_angle = 1 - steering_angle
#         steering_angle = (80 - steering_angle*80)/80
        #(180 - (steering_angle[0]*80 + 50) -50)/80
   
    return image, steering_angle

# %%
def random_augment(image, steering_angle):
    if np.random.rand() < 0.5:
        image = pan(image)
    if np.random.rand() < 0.5:
        image = zoom(image)
#     if np.random.rand() < 0.5:
#         image = blur(image)
#     if np.random.rand() < 0.5:
#         image = adjust_brightness(image)
    if np.random.rand() < 0.75:
        image, steering_angle = random_flip(image, steering_angle)
    
    return image, steering_angle



# show a few randomly augmented images
# ncol = 2
# nrow = 10
# fig, axes = plt.subplots(nrow, ncol, figsize=(15, 50))

# for i in range(nrow):
#     rand_index = random.randint(0, len(image_paths) - 1)
#     image_path = image_paths[rand_index]
#     steering_angle_orig = steering_angles[rand_index]
    
#     image_orig = my_imread(image_path)
#     image_aug, steering_angle_aug = random_augment(image_orig, steering_angle_orig)
    
#     axes[i][0].imshow(image_orig)
#     axes[i][0].set_title("original, angle=%s" % steering_angle_orig)
#     axes[i][1].imshow(image_aug)
#     axes[i][1].set_title("augmented, angle=%s" % steering_angle_aug)

# %%
def img_preprocess(image):
    height, _, _ = image.shape
#     image = image[int(height/2):,:,:]
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Nvidia model said it is best to use YUV color space
#     image = cv2.GaussianBlur(image, (3,3), 0)
    image = cv2.resize(image, (160,120)) # input image size (200,66) Nvidia model
#     image[85:,:] = 255 - image[85:,:]
    image = image / 255 # normalizing
    return image

# %%
ncol = 2
nrow = 2

X_train_batch, y_train_batch = next(image_data_generator(X_train, y_train, nrow, True))
X_valid_batch, y_valid_batch = next(image_data_generator(X_valid, y_valid, nrow, False))

fig, axes = plt.subplots(nrow, ncol, figsize=(15, 6))
fig.tight_layout()

for i in range(nrow):
    axes[i][0].imshow(X_train_batch[i])
    axes[i][0].set_title("training, speed=%s" % y_train_batch[i])
    axes[i][1].imshow(X_valid_batch[i])
    axes[i][1].set_title("validation, speed=%s" % y_valid_batch[i])

# %%
print(np.shape(X_train_batch[0]))
# Out:
# (120, 160, 3)

# %%
inp1 = Input(shape=(120, 160, 3))

x = Conv2D(32, (5, 5), strides=(2, 2), activation='elu')(inp1)
x = Conv2D(32, (5, 5), strides=(2, 2), activation='elu')(x)
# x = MaxPooling2D(pool_size=(3, 3),strides=2)(x)
# x2 = Dropout(0.2)(x2)
x = Conv2D(48, (5, 5), activation='elu')(x)
x = Conv2D(48, (5, 5), activation='elu')(x)
x = MaxPooling2D(pool_size=(2, 2),strides=2)(x)

x = Conv2D(64, (3, 3), activation='elu')(x)
x = Conv2D(64, (3, 3), activation='elu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2, 2),strides=2)(x)
# x = Dropout(0.3)(x)
x = Flatten()(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='elu')(x)
x = Dense(100, activation='elu')(x)
x = BatchNormalization()(x)

x1 = Dense(50, activation='elu')(x)
x1 = Dense(10, activation='elu')(x1)
# x = BatchNormalization()(x)
out = Dense(1, activation='sigmoid', name='speed')(x1) 


model = keras.Model(inputs=[inp1], outputs=out)
model.summary()
# loss_weights = [0.9, 0.1]
optimizer = Adam(lr=1e-3) # lr is learning rate
model.compile(loss='binary_crossentropy', optimizer=optimizer)#, loss_weights = loss_weights )
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 120, 160, 3)]     0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 58, 78, 32)        2432
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 27, 37, 32)        25632
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 23, 33, 48)        38448
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 19, 29, 48)        57648
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 9, 14, 48)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 7, 12, 64)         27712
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 5, 10, 64)         36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 10, 64)         256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 5, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 640)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               164096
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               25700
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 100)               400
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                510
# _________________________________________________________________
# speed (Dense)                (None, 1)                 11
# =================================================================
# Total params: 384,823
# Trainable params: 384,495
# Non-trainable params: 328
# _________________________________________________________________

# %%
batch_size = 32
train_steps = int(np.floor(len(X_train) / batch_size))
valid_steps = int(np.floor(len(X_valid) / batch_size))
print(train_steps, valid_steps)
# Out:
# 971 242

# %%
# saves the model weights after each epoch if the validation loss decreased
model_output_dir = '/Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(model_output_dir,'Speed_NoTL{epoch:04d}.h5'), verbose=1, save_best_only=True)

history = model.fit_generator(image_data_generator( X_train, y_train, batch_size=batch_size, is_training=True),
                              steps_per_epoch=train_steps,
                              epochs=50,
                              validation_data = image_data_generator( X_valid, y_valid, batch_size=100, is_training=False),
                              validation_steps=valid_steps, 
                              verbose=1,
                              shuffle=1,
                              callbacks=[checkpoint_callback])
# always save model output as soon as model finishes training
model.save(os.path.join(model_output_dir,'Speed_NoTL_model.h5'))
# Out:
# Epoch 1/50
# 971/971 [==============================] - 643s 662ms/step - loss: 0.3998 - val_loss: 0.5054
#
# Epoch 00001: val_loss improved from inf to 0.50536, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0001.h5
# Epoch 2/50
# 971/971 [==============================] - 659s 679ms/step - loss: 0.2374 - val_loss: 0.2301
#
# Epoch 00002: val_loss improved from 0.50536 to 0.23011, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0002.h5
# Epoch 3/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.1987 - val_loss: 0.1727
#
# Epoch 00003: val_loss improved from 0.23011 to 0.17272, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0003.h5
# Epoch 4/50
# 971/971 [==============================] - 659s 679ms/step - loss: 0.1520 - val_loss: 0.3200
#
# Epoch 00004: val_loss did not improve from 0.17272
# Epoch 5/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.1269 - val_loss: 0.1551
#
# Epoch 00005: val_loss improved from 0.17272 to 0.15511, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0005.h5
# Epoch 6/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.0956 - val_loss: 0.1050
#
# Epoch 00006: val_loss improved from 0.15511 to 0.10499, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0006.h5
# Epoch 7/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.0864 - val_loss: 0.0906
#
# Epoch 00007: val_loss improved from 0.10499 to 0.09062, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0007.h5
# Epoch 8/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.0690 - val_loss: 0.0800
#
# Epoch 00008: val_loss improved from 0.09062 to 0.08001, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0008.h5
# Epoch 9/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.0540 - val_loss: 0.0825
#
# Epoch 00009: val_loss did not improve from 0.08001
# Epoch 10/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.0493 - val_loss: 0.0606
#
# Epoch 00010: val_loss improved from 0.08001 to 0.06058, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0010.h5
# Epoch 11/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.0349 - val_loss: 0.0510
#
# Epoch 00011: val_loss improved from 0.06058 to 0.05103, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0011.h5
# Epoch 12/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.0346 - val_loss: 0.0576
#
# Epoch 00012: val_loss did not improve from 0.05103
# Epoch 13/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.0344 - val_loss: 0.0606
#
# Epoch 00013: val_loss did not improve from 0.05103
# Epoch 14/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.0312 - val_loss: 0.0711
#
# Epoch 00014: val_loss did not improve from 0.05103
# Epoch 15/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.0312 - val_loss: 0.0503
#
# Epoch 00015: val_loss improved from 0.05103 to 0.05027, saving model to /Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/Speed_NoTL0015.h5
# Epoch 16/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.0214 - val_loss: 0.0830
#
# Epoch 00016: val_loss did not improve from 0.05027
# Epoch 17/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.0300 - val_loss: 0.0905
#
# Epoch 00017: val_loss did not improve from 0.05027
# Epoch 18/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.0122 - val_loss: 0.0578
#
# Epoch 00018: val_loss did not improve from 0.05027
# Epoch 19/50
# 971/971 [==============================] - 662s 682ms/step - loss: -0.0119 - val_loss: 0.6211
#
# Epoch 00019: val_loss did not improve from 0.05027
# Epoch 20/50
# 971/971 [==============================] - 660s 679ms/step - loss: 0.2721 - val_loss: 0.0753
#
# Epoch 00020: val_loss did not improve from 0.05027
# Epoch 21/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.0107 - val_loss: 0.0893
#
# Epoch 00021: val_loss did not improve from 0.05027
# Epoch 22/50
# 971/971 [==============================] - 661s 681ms/step - loss: -0.0637 - val_loss: 0.0703
#
# Epoch 00022: val_loss did not improve from 0.05027
# Epoch 23/50
# 971/971 [==============================] - 662s 682ms/step - loss: -0.0548 - val_loss: 0.5814
#
# Epoch 00023: val_loss did not improve from 0.05027
# Epoch 24/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.8880 - val_loss: 0.5504
#
# Epoch 00024: val_loss did not improve from 0.05027
# Epoch 25/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.3057 - val_loss: 0.2053
#
# Epoch 00025: val_loss did not improve from 0.05027
# Epoch 26/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.1933 - val_loss: 0.1162
#
# Epoch 00026: val_loss did not improve from 0.05027
# Epoch 27/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.1336 - val_loss: 0.2090
#
# Epoch 00027: val_loss did not improve from 0.05027
# Epoch 28/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.1684 - val_loss: 0.1041
#
# Epoch 00028: val_loss did not improve from 0.05027
# Epoch 29/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.2376 - val_loss: 0.2296
#
# Epoch 00029: val_loss did not improve from 0.05027
# Epoch 30/50
# 971/971 [==============================] - 664s 684ms/step - loss: 0.1083 - val_loss: 0.0706
#
# Epoch 00030: val_loss did not improve from 0.05027
# Epoch 31/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.0797 - val_loss: 0.1420
#
# Epoch 00031: val_loss did not improve from 0.05027
# Epoch 32/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.1161 - val_loss: 0.0691
#
# Epoch 00032: val_loss did not improve from 0.05027
# Epoch 33/50
# 971/971 [==============================] - 663s 683ms/step - loss: 0.0514 - val_loss: 0.3845
#
# Epoch 00033: val_loss did not improve from 0.05027
# Epoch 34/50
# 971/971 [==============================] - 660s 680ms/step - loss: -0.1193 - val_loss: 2.1407
#
# Epoch 00034: val_loss did not improve from 0.05027
# Epoch 35/50
# 971/971 [==============================] - 663s 683ms/step - loss: 0.3787 - val_loss: 4.6952
#
# Epoch 00035: val_loss did not improve from 0.05027
# Epoch 36/50
# 971/971 [==============================] - 660s 679ms/step - loss: 0.4960 - val_loss: 0.9724
#
# Epoch 00036: val_loss did not improve from 0.05027
# Epoch 37/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.4451 - val_loss: 0.4275
#
# Epoch 00037: val_loss did not improve from 0.05027
# Epoch 38/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.3853 - val_loss: 0.9891
#
# Epoch 00038: val_loss did not improve from 0.05027
# Epoch 39/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.3169 - val_loss: 77.4700
#
# Epoch 00039: val_loss did not improve from 0.05027
# Epoch 40/50
# 971/971 [==============================] - 663s 683ms/step - loss: 0.2619 - val_loss: 664.3326
#
# Epoch 00040: val_loss did not improve from 0.05027
# Epoch 41/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.2420 - val_loss: 3753.3354
#
# Epoch 00041: val_loss did not improve from 0.05027
# Epoch 42/50
# 971/971 [==============================] - 661s 681ms/step - loss: 0.2773 - val_loss: 0.6253
#
# Epoch 00042: val_loss did not improve from 0.05027
# Epoch 43/50
# 971/971 [==============================] - 660s 680ms/step - loss: 0.2279 - val_loss: 2.3267
#
# Epoch 00043: val_loss did not improve from 0.05027
# Epoch 44/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.1855 - val_loss: 0.2662
#
# Epoch 00044: val_loss did not improve from 0.05027
# Epoch 45/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.1550 - val_loss: 14.0848
#
# Epoch 00045: val_loss did not improve from 0.05027
# Epoch 46/50
# 971/971 [==============================] - 662s 682ms/step - loss: 0.1340 - val_loss: 0.3820
#
# Epoch 00046: val_loss did not improve from 0.05027
# Epoch 47/50
# 971/971 [==============================] - 663s 683ms/step - loss: 0.1207 - val_loss: 249.4064
#
# Epoch 00047: val_loss did not improve from 0.05027
# Epoch 48/50
# 971/971 [==============================] - 663s 683ms/step - loss: 0.0923 - val_loss: 20.9048
#
# Epoch 00048: val_loss did not improve from 0.05027
# Epoch 49/50
# 971/971 [==============================] - 664s 684ms/step - loss: 0.0805 - val_loss: 0.0797
#
# Epoch 00049: val_loss did not improve from 0.05027
# Epoch 50/50
# 971/971 [==============================] - 664s 684ms/step - loss: 0.0598 - val_loss: 0.0648
#
# Epoch 00050: val_loss did not improve from 0.05027

# %%
df = pd.DataFrame(history.history)
print(history.history.keys())
# # summarize history for accuracy
# plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
model_output_dir = '/Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/'
from sklearn.metrics import mean_squared_error, r2_score

def summarize_prediction(Y_true, Y_pred):
    
    mse = mean_squared_error(Y_true, Y_pred)
    r_squared = r2_score(Y_true, Y_pred)
    
    
    print(f'mse       = {mse:.2}')
    print(f'r_squared = {r_squared:.2%}')
    print()
    
def predict_and_summarize(X, Y):
    model = load_model(f'{model_output_dir}/Speed_NoTL_model.h5')
    Y_pred = model.predict(X)
#     summarize_prediction(Y, Y_pred)
    return Y_pred

# %%
n_tests = 100
X_test, y_test = next(image_data_generator(X_valid, y_valid, 100, False))

y_pred = predict_and_summarize(X_test, y_test)

n_tests_show = 10
fig, axes = plt.subplots(n_tests_show, 1, figsize=(10, 4 * n_tests_show))
for i in range(n_tests_show):
    axes[i].imshow(X_test[i])
    axes[i].set_title(f"actual speed={y_test[i]}, predicted speed={(y_pred[i])}, diff = {(y_pred[i])-y_test[i]}")

# %%
model = load_model(f'{model_output_dir}/Speed_NoTL_model.h5')
path_file = '/Users/kamyab/Documents/UoN/MLiS_2/Project/Data/test_data/test_data/'
test_names = np.arange(1020) + 1
# with open(path_file + 'submission2.csv', mode='w', newline='') as submission:
#     writer = csv.writer(submission, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#     writer.writerow(['image_id', 'angle', 'speed'])
# for name in test_names[3]:     
img = cv2.imread(path_file + str(test_names[328]) + '.png')
#         print(img)
prediction = compute_steering_angle(model, img)
        
print(prediction)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-902b551e5938> in <module>
#       8 img = cv2.imread(path_file + str(test_names[328]) + '.png')
#       9 #         print(img)
# ---> 10 prediction = compute_steering_angle(model, img)
#      11
#      12 print(prediction)
#
# NameError: name 'compute_steering_angle' is not defined

# %%
model_output_dir = '/Users/Kamyab/Documents/UoN/MLiS_2/Project/All models/NoTLspeed/'
model = load_model(os.path.join(model_output_dir,'Speed_NoTL_model.h5'))
       
def compute_steering_angle(self, frame):
    preprocessed = img_preprocess(frame)
    X = np.asarray([preprocessed])
    steering_angle = model.predict(X)
    return steering_angle

# %%
path_file = '/Users/kamyab/Documents/UoN/MLiS_2/Project/Data/test_data/test_data/'
img = cv2.imread(path_file + str(1020)+'.png')
print(compute_steering_angle(model, img)[0][0])
plt.imshow(img)
# Out:
# 0.9817979

# %%
path_file = '/Users/kamyab/Documents/UoN/MLiS_2/Project/Data/test_data/test_data/'

test_names = np.arange(1020) + 1
with open(path_file + 'speed2May.csv', mode='w', newline='') as submission:
    writer = csv.writer(submission, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['image_id', 'speed'])
 
#     fig, axes = plt.subplots(n_tests_show, 1, figsize=(10, 4 * n_tests_show))
    for name in test_names:     
        img = cv2.imread(path_file + str(name) + '.png')
        prediction = compute_steering_angle(model, img)
        
#         if prediction[0][0] > 0.5:
#             speed = 1
#         else:
#             speed = 0    
#         writer.writerow([name, prediction])
        print('{0},{1:0.2f}'.format(name, prediction[0][0]))
# Out:
# 1,0.00
# 2,0.95
# 3,0.71
# 4,0.84
# 5,0.86
# 6,0.83
# 7,0.91
# 8,0.94
# 9,0.00
# 10,0.75
# 11,0.00
# 12,0.00
# 13,0.99
# 14,0.00
# 15,0.98
# 16,0.44
# 17,0.00
# 18,0.01
# 19,0.00
# 20,0.98
# 21,0.98
# 22,0.85
# 23,0.87
# 24,0.00
# 25,0.02
# 26,0.96
# 27,0.00
# 28,0.00
# 29,0.00
# 30,0.99
# 31,0.92
# 32,0.90
# 33,0.00
# 34,1.00
# 35,0.00
# 36,0.92
# 37,0.97
# 38,0.90
# 39,0.00
# 40,0.96
# 41,0.94
# 42,0.00
# 43,0.91
# 44,0.05
# 45,1.00
# 46,0.00
# 47,0.00
# 48,0.02
# 49,0.87
# 50,0.21
# 51,0.86
# 52,0.53
# 53,0.00
# 54,0.73
# 55,0.00
# 56,0.00
# 57,0.00
# 58,0.00
# 59,0.81
# 60,0.99
# 61,0.00
# 62,0.96
# 63,0.88
# 64,0.00
# 65,0.52
# 66,0.00
# 67,0.00
# 68,0.00
# 69,0.93
# 70,0.00
# 71,0.99
# 72,0.00
# 73,0.00
# 74,0.49
# 75,0.10
# 76,0.98
# 77,0.94
# 78,0.91
# 79,1.00
# 80,0.81
# 81,0.88
# 82,0.98
# 83,0.12
# 84,0.33
# 85,0.96
# 86,0.10
# 87,0.99
# 88,0.40
# 89,0.15
# 90,0.89
# 91,0.89
# 92,0.88
# 93,0.02
# 94,0.99
# 95,0.00
# 96,0.00
# 97,0.88
# 98,0.00
# 99,0.67
# 100,0.95
# 101,0.01
# 102,0.87
# 103,0.90
# 104,0.18
# 105,0.58
# 106,0.00
# 107,0.01
# 108,1.00
# 109,0.98
# 110,0.00
# 111,0.95
# 112,0.00
# 113,0.00
# 114,0.00
# 115,0.02
# 116,0.94
# 117,0.01
# 118,0.95
# 119,0.81
# 120,0.00
# 121,0.89
# 122,0.01
# 123,0.10
# 124,0.00
# 125,0.91
# 126,0.00
# 127,0.95
# 128,0.52
# 129,0.97
# 130,0.00
# 131,0.02
# 132,0.72
# 133,0.86
# 134,0.93
# 135,0.99
# 136,0.00
# 137,0.01
# 138,0.05
# 139,0.66
# 140,0.00
# 141,0.81
# 142,0.91
# 143,0.05
# 144,0.51
# 145,0.97
# 146,0.81
# 147,0.02
# 148,0.52
# 149,0.07
# 150,0.02
# 151,1.00
# 152,0.00
# 153,0.00
# 154,0.99
# 155,0.00
# 156,0.01
# 157,0.00
# 158,0.98
# 159,0.91
# 160,0.72
# 161,0.77
# 162,0.98
# 163,0.00
# 164,0.97
# 165,0.00
# 166,0.01
# 167,0.01
# 168,0.97
# 169,0.95
# 170,0.97
# 171,0.05
# 172,0.97
# 173,0.02
# 174,0.96
# 175,1.00
# 176,0.00
# 177,0.94
# 178,0.97
# 179,0.08
# 180,0.95
# 181,0.98
# 182,0.94
# 183,0.30
# 184,0.00
# 185,0.99
# 186,1.00
# 187,0.56
# 188,0.00
# 189,0.00
# 190,0.00
# 191,0.10
# 192,0.59
# 193,0.07
# 194,0.98
# 195,0.26
# 196,0.88
# 197,0.00
# 198,0.00
# 199,0.91
# 200,0.00
# 201,0.78
# 202,0.99
# 203,0.00
# 204,0.95
# 205,0.75
# 206,0.00
# 207,0.00
# 208,0.00
# 209,0.62
# 210,0.88
# 211,0.99
# 212,0.94
# 213,0.89
# 214,0.95
# 215,0.00
# 216,0.00
# 217,0.01
# 218,0.74
# 219,0.09
# 220,0.00
# 221,0.00
# 222,0.01
# 223,0.72
# 224,0.96
# 225,0.72
# 226,0.99
# 227,0.99
# 228,0.89
# 229,1.00
# 230,0.55
# 231,0.95
# 232,0.97
# 233,0.01
# 234,0.00
# 235,0.92
# 236,0.00
# 237,0.43
# 238,0.03
# 239,0.04
# 240,0.79
# 241,0.01
# 242,0.00
# 243,0.00
# 244,0.00
# 245,0.98
# 246,0.29
# 247,0.22
# 248,0.96
# 249,0.96
# 250,0.96
# 251,0.97
# 252,0.00
# 253,0.00
# 254,0.00
# 255,0.01
# 256,0.83
# 257,0.00
# 258,1.00
# 259,0.98
# 260,0.00
# 261,0.99
# 262,0.01
# 263,0.98
# 264,0.00
# 265,0.00
# 266,0.00
# 267,0.08
# 268,0.92
# 269,0.00
# 270,0.25
# 271,1.00
# 272,0.96
# 273,0.00
# 274,0.00
# 275,0.97
# 276,0.89
# 277,0.39
# 278,0.99
# 279,0.00
# 280,0.99
# 281,0.00
# 282,0.00
# 283,0.99
# 284,0.11
# 285,0.54
# 286,0.00
# 287,0.04
# 288,0.01
# 289,0.00
# 290,0.98
# 291,0.00
# 292,0.93
# 293,0.96
# 294,0.33
# 295,0.01
# 296,1.00
# 297,0.14
# 298,0.05
# 299,0.99
# 300,0.00
# 301,0.00
# 302,0.99
# 303,0.63
# 304,0.00
# 305,0.96
# 306,0.00
# 307,1.00
# 308,0.73
# 309,0.52
# 310,0.92
# 311,0.50
# 312,1.00
# 313,0.98
# 314,0.79
# 315,0.36
# 316,0.01
# 317,0.97
# 318,0.90
# 319,0.88
# 320,0.28
# 321,0.20
# 322,0.49
# 323,0.95
# 324,0.00
# 325,0.00
# 326,0.45
# 327,0.91
# 328,0.00
# 329,0.99
# 330,0.98
# 331,0.03
# 332,0.14
# 333,0.00
# 334,0.00
# 335,0.00
# 336,0.91
# 337,0.42
# 338,0.02
# 339,0.49
# 340,0.47
# 341,0.63
# 342,0.94
# 343,0.90
# 344,0.01
# 345,0.00
# 346,0.00
# 347,0.00
# 348,0.87
# 349,0.43
# 350,0.02
# 351,0.00
# 352,0.00
# 353,0.79
# 354,0.94
# 355,0.00
# 356,0.87
# 357,0.99
# 358,1.00
# 359,0.00
# 360,0.66
# 361,1.00
# 362,0.66
# 363,0.98
# 364,0.26
# 365,0.97
# 366,0.96
# 367,0.81
# 368,0.62
# 369,0.91
# 370,0.36
# 371,0.02
# 372,0.00
# 373,0.01
# 374,0.01
# 375,0.98
# 376,0.96
# 377,0.97
# 378,0.87
# 379,0.00
# 380,0.00
# 381,1.00
# 382,1.00
# 383,0.98
# 384,0.91
# 385,0.69
# 386,0.00
# 387,0.00
# 388,0.98
# 389,0.39
# 390,0.98
# 391,0.97
# 392,0.15
# 393,0.00
# 394,0.00
# 395,0.14
# 396,0.53
# 397,1.00
# 398,0.00
# 399,0.00
# 400,0.98
# 401,0.87
# 402,0.95
# 403,0.71
# 404,0.59
# 405,0.98
# 406,0.82
# 407,0.00
# 408,0.00
# 409,0.86
# 410,0.03
# 411,1.00
# 412,0.25
# 413,0.00
# 414,0.00
# 415,0.33
# 416,0.71
# 417,0.71
# 418,0.00
# 419,0.00
# 420,0.86
# 421,0.01
# 422,0.00
# 423,0.97
# 424,0.85
# 425,0.02
# 426,0.86
# 427,0.00
# 428,0.25
# 429,1.00
# 430,0.16
# 431,0.01
# 432,0.98
# 433,0.00
# 434,0.05
# 435,0.98
# 436,0.00
# 437,0.97
# 438,0.00
# 439,0.95
# 440,0.99
# 441,0.54
# 442,0.68
# 443,0.37
# 444,0.00
# 445,0.99
# 446,0.99
# 447,1.00
# 448,0.00
# 449,0.94
# 450,0.10
# 451,0.00
# 452,0.84
# 453,0.71
# 454,0.83
# 455,0.42
# 456,0.88
# 457,0.33
# 458,0.89
# 459,0.00
# 460,0.70
# 461,0.03
# 462,0.00
# 463,0.96
# 464,0.00
# 465,0.00
# 466,0.00
# 467,0.01
# 468,0.14
# 469,0.92
# 470,0.00
# 471,0.00
# 472,0.99
# 473,0.94
# 474,0.02
# 475,0.97
# 476,0.98
# 477,0.98
# 478,0.99
# 479,1.00
# 480,0.02
# 481,0.00
# 482,0.03
# 483,0.57
# 484,0.89
# 485,0.92
# 486,0.99
# 487,0.21
# 488,0.01
# 489,0.97
# 490,0.72
# 491,0.61
# 492,0.85
# 493,0.97
# 494,0.87
# 495,0.95
# 496,0.81
# 497,0.00
# 498,0.97
# 499,0.01
# 500,0.03
# 501,0.93
# 502,0.23
# 503,0.01
# 504,0.09
# 505,0.96
# 506,0.01
# 507,0.80
# 508,0.04
# 509,0.77
# 510,0.86
# 511,0.82
# 512,0.86
# 513,0.00
# 514,0.00
# 515,0.89
# 516,0.00
# 517,0.97
# 518,0.97
# 519,0.97
# 520,0.08
# 521,0.00
# 522,0.94
# 523,0.96
# 524,0.03
# 525,0.00
# 526,0.00
# 527,0.94
# 528,0.50
# 529,1.00
# 530,0.00
# 531,0.00
# 532,0.95
# 533,0.00
# 534,0.00
# 535,0.98
# 536,0.53
# 537,0.86
# 538,0.35
# 539,0.01
# 540,0.99
# 541,1.00
# 542,0.00
# 543,0.83
# 544,0.98
# 545,0.83
# 546,1.00
# 547,0.09
# 548,0.02
# 549,0.00
# 550,0.01
# 551,0.99
# 552,1.00
# 553,0.01
# 554,0.98
# 555,0.98
# 556,0.16
# 557,1.00
# 558,0.01
# 559,0.89
# 560,0.00
# 561,0.00
# 562,0.00
# 563,0.99
# 564,0.01
# 565,0.92
# 566,0.97
# 567,0.00
# 568,0.02
# 569,0.98
# 570,0.28
# 571,0.01
# 572,0.18
# 573,0.92
# 574,1.00
# 575,0.91
# 576,0.76
# 577,0.95
# 578,0.61
# 579,0.98
# 580,0.92
# 581,0.81
# 582,0.87
# 583,0.97
# 584,0.98
# 585,0.00
# 586,0.90
# 587,0.00
# 588,0.98
# 589,1.00
# 590,0.00
# 591,0.97
# 592,0.95
# 593,0.98
# 594,0.00
# 595,0.75
# 596,0.79
# 597,0.69
# 598,0.99
# 599,0.96
# 600,0.00
# 601,0.00
# 602,0.92
# 603,1.00
# 604,0.59
# 605,0.84
# 606,0.93
# 607,0.99
# 608,0.00
# 609,0.54
# 610,0.99
# 611,0.95
# 612,0.53
# 613,0.00
# 614,0.02
# 615,0.92
# 616,0.97
# 617,0.00
# 618,0.00
# 619,0.00
# 620,0.00
# 621,0.98
# 622,0.00
# 623,0.06
# 624,0.96
# 625,0.54
# 626,0.98
# 627,0.92
# 628,0.91
# 629,0.01
# 630,0.98
# 631,0.78
# 632,0.94
# 633,0.88
# 634,1.00
# 635,0.00
# 636,0.07
# 637,0.17
# 638,0.00
# 639,0.00
# 640,0.00
# 641,0.98
# 642,0.99
# 643,0.00
# 644,0.93
# 645,0.00
# 646,0.00
# 647,0.01
# 648,0.00
# 649,0.12
# 650,0.13
# 651,0.00
# 652,0.00
# 653,0.95
# 654,0.00
# 655,0.84
# 656,0.00
# 657,0.97
# 658,0.98
# 659,0.00
# 660,0.00
# 661,1.00
# 662,0.96
# 663,0.00
# 664,0.88
# 665,0.00
# 666,0.01
# 667,0.99
# 668,0.92
# 669,0.00
# 670,0.04
# 671,0.62
# 672,0.00
# 673,0.00
# 674,0.00
# 675,0.99
# 676,1.00
# 677,0.50
# 678,0.00
# 679,0.01
# 680,0.98
# 681,0.00
# 682,0.81
# 683,0.91
# 684,0.01
# 685,0.00
# 686,0.00
# 687,0.35
# 688,0.95
# 689,0.00
# 690,0.00
# 691,0.96
# 692,0.87
# 693,0.24
# 694,0.19
# 695,0.96
# 696,0.76
# 697,0.02
# 698,0.89
# 699,0.19
# 700,1.00
# 701,0.00
# 702,0.42
# 703,0.79
# 704,0.97
# 705,0.94
# 706,0.97
# 707,0.33
# 708,0.62
# 709,0.94
# 710,0.00
# 711,0.98
# 712,0.47
# 713,0.97
# 714,0.00
# 715,0.70
# 716,0.03
# 717,0.18
# 718,0.00
# 719,1.00
# 720,0.00
# 721,0.00
# 722,0.96
# 723,0.00
# 724,0.00
# 725,0.73
# 726,0.00
# 727,1.00
# 728,0.33
# 729,0.85
# 730,0.08
# 731,0.66
# 732,0.03
# 733,0.94
# 734,0.48
# 735,0.91
# 736,0.00
# 737,0.00
# 738,0.69
# 739,0.00
# 740,0.99
# 741,1.00
# 742,0.01
# 743,0.95
# 744,0.02
# 745,0.00
# 746,0.00
# 747,0.01
# 748,0.00
# 749,0.61
# 750,0.00
# 751,0.97
# 752,0.98
# 753,0.01
# 754,0.68
# 755,0.00
# 756,0.90
# 757,0.79
# 758,0.00
# 759,0.99
# 760,0.00
# 761,0.95
# 762,0.00
# 763,0.38
# 764,0.84
# 765,0.99
# 766,0.92
# 767,0.00
# 768,0.96
# 769,0.96
# 770,0.00
# 771,0.94
# 772,0.86
# 773,0.96
# 774,0.97
# 775,0.02
# 776,0.00
# 777,0.42
# 778,0.00
# 779,0.98
# 780,0.81
# 781,0.99
# 782,0.99
# 783,0.96
# 784,0.28
# 785,0.98
# 786,0.00
# 787,0.96
# 788,1.00
# 789,0.00
# 790,0.80
# 791,0.20
# 792,0.98
# 793,0.99
# 794,0.96
# 795,0.00
# 796,0.00
# 797,0.02
# 798,0.39
# 799,0.98
# 800,0.08
# 801,0.14
# 802,0.97
# 803,0.00
# 804,1.00
# 805,0.00
# 806,0.93
# 807,0.00
# 808,0.00
# 809,0.00
# 810,0.68
# 811,0.86
# 812,0.47
# 813,0.80
# 814,0.84
# 815,0.99
# 816,0.99
# 817,0.00
# 818,0.03
# 819,0.00
# 820,0.98
# 821,1.00
# 822,0.62
# 823,0.01
# 824,0.00
# 825,0.07
# 826,0.99
# 827,0.00
# 828,0.28
# 829,0.88
# 830,0.97
# 831,0.16
# 832,0.77
# 833,0.93
# 834,0.67
# 835,0.87
# 836,0.71
# 837,0.02
# 838,0.00
# 839,0.00
# 840,0.90
# 841,0.00
# 842,0.98
# 843,0.00
# 844,0.16
# 845,0.00
# 846,0.90
# 847,0.69
# 848,0.08
# 849,1.00
# 850,0.03
# 851,0.00
# 852,0.01
# 853,0.98
# 854,0.61
# 855,0.00
# 856,1.00
# 857,0.21
# 858,0.91
# 859,0.00
# 860,0.60
# 861,0.00
# 862,1.00
# 863,0.00
# 864,0.99
# 865,0.00
# 866,0.97
# 867,0.98
# 868,0.02
# 869,0.00
# 870,0.05
# 871,1.00
# 872,0.91
# 873,0.12
# 874,0.99
# 875,0.91
# 876,0.89
# 877,0.96
# 878,0.86
# 879,0.98
# 880,1.00
# 881,0.99
# 882,1.00
# 883,0.99
# 884,0.64
# 885,0.01
# 886,0.99
# 887,0.31
# 888,0.00
# 889,0.52
# 890,0.01
# 891,0.96
# 892,0.90
# 893,0.99
# 894,1.00
# 895,1.00
# 896,0.98
# 897,0.00
# 898,0.00
# 899,0.00
# 900,0.02
# 901,0.00
# 902,0.86
# 903,0.67
# 904,0.99
# 905,0.91
# 906,0.00
# 907,1.00
# 908,0.28
# 909,0.00
# 910,0.00
# 911,0.00
# 912,0.11
# 913,1.00
# 914,0.17
# 915,0.92
# 916,0.00
# 917,0.00
# 918,0.09
# 919,0.00
# 920,0.00
# 921,0.01
# 922,0.99
# 923,0.84
# 924,1.00
# 925,0.86
# 926,0.99
# 927,0.82
# 928,1.00
# 929,0.97
# 930,0.00
# 931,0.29
# 932,0.00
# 933,0.80
# 934,0.99
# 935,0.00
# 936,0.69
# 937,0.93
# 938,0.00
# 939,0.98
# 940,0.85
# 941,0.69
# 942,0.00
# 943,0.00
# 944,0.00
# 945,0.92
# 946,0.00
# 947,0.97
# 948,0.78
# 949,0.99
# 950,0.97
# 951,0.98
# 952,0.84
# 953,0.00
# 954,0.00
# 955,0.74
# 956,0.94
# 957,0.00
# 958,1.00
# 959,0.48
# 960,0.69
# 961,0.98
# 962,0.99
# 963,0.15
# 964,0.00
# 965,0.00
# 966,1.00
# 967,0.91
# 968,0.03
# 969,0.00
# 970,0.98
# 971,1.00
# 972,0.99
# 973,0.01
# 974,0.13
# 975,0.90
# 976,0.93
# 977,0.00
# 978,0.98
# 979,0.98
# 980,0.78
# 981,0.46
# 982,1.00
# 983,0.00
# 984,0.66
# 985,0.04
# 986,0.99
# 987,0.66
# 988,0.00
# 989,0.00
# 990,0.94
# 991,0.98
# 992,0.99
# 993,0.48
# 994,0.00
# 995,0.00
# 996,0.00
# 997,0.01
# 998,0.01
# 999,0.86
# 1000,0.87
# 1001,0.93
# 1002,1.00
# 1003,0.01
# 1004,0.00
# 1005,1.00
# 1006,0.00
# 1007,0.91
# 1008,0.00
# 1009,0.98
# 1010,0.00
# 1011,0.94
# 1012,0.00
# 1013,1.00
# 1014,0.79
# 1015,0.47
# 1016,0.66
# 1017,0.48
# 1018,0.98
# 1019,0.56
# 1020,0.98
